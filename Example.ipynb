# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df=pd.read_csv('countries.csv')
df
# Out:
#           country  year  population
# 0     Afghanistan  1952     8425333
# 1     Afghanistan  1957     9240934
# 2     Afghanistan  1962    10267083
# 3     Afghanistan  1967    11537966
# 4     Afghanistan  1972    13079460
# ...           ...   ...         ...
# 1699     Zimbabwe  1987     9216418
# 1700     Zimbabwe  1992    10704340
# 1701     Zimbabwe  1997    11404948
# 1702     Zimbabwe  2002    11926563
# 1703     Zimbabwe  2007    12311143
#
# [1704 rows x 3 columns]

# %%
df.shape
# Out:
# (1704, 3)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of           country  year  population
# 0     Afghanistan  1952     8425333
# 1     Afghanistan  1957     9240934
# 2     Afghanistan  1962    10267083
# 3     Afghanistan  1967    11537966
# 4     Afghanistan  1972    13079460
# ...           ...   ...         ...
# 1699     Zimbabwe  1987     9216418
# 1700     Zimbabwe  1992    10704340
# 1701     Zimbabwe  1997    11404948
# 1702     Zimbabwe  2002    11926563
# 1703     Zimbabwe  2007    12311143
#
# [1704 rows x 3 columns]>

# %%
df.head(50)
# Out:
#         country  year  population
# 0   Afghanistan  1952     8425333
# 1   Afghanistan  1957     9240934
# 2   Afghanistan  1962    10267083
# 3   Afghanistan  1967    11537966
# 4   Afghanistan  1972    13079460
# 5   Afghanistan  1977    14880372
# 6   Afghanistan  1982    12881816
# 7   Afghanistan  1987    13867957
# 8   Afghanistan  1992    16317921
# 9   Afghanistan  1997    22227415
# 10  Afghanistan  2002    25268405
# 11  Afghanistan  2007    31889923
# 12      Albania  1952     1282697
# 13      Albania  1957     1476505
# 14      Albania  1962     1728137
# 15      Albania  1967     1984060
# 16      Albania  1972     2263554
# 17      Albania  1977     2509048
# 18      Albania  1982     2780097
# 19      Albania  1987     3075321
# 20      Albania  1992     3326498
# 21      Albania  1997     3428038
# 22      Albania  2002     3508512
# 23      Albania  2007     3600523
# 24      Algeria  1952     9279525
# 25      Algeria  1957    10270856
# ...

# %%
df.tail(7)
# Out:
#        country  year  population
# 1697  Zimbabwe  1977     6642107
# 1698  Zimbabwe  1982     7636524
# 1699  Zimbabwe  1987     9216418
# 1700  Zimbabwe  1992    10704340
# 1701  Zimbabwe  1997    11404948
# 1702  Zimbabwe  2002    11926563
# 1703  Zimbabwe  2007    12311143

# %%
df.isnull().sum()
# Out:
# country       0
# year          0
# population    0
# dtype: int64

# %%
df.dtypes
# Out:
# country       object
# year           int64
# population     int64
# dtype: object

# %%
som=df[df['country']=='Somalia']
som
# Out:
#       country  year  population
# 1392  Somalia  1952     2526994
# 1393  Somalia  1957     2780415
# 1394  Somalia  1962     3080153
# 1395  Somalia  1967     3428839
# 1396  Somalia  1972     3840161
# 1397  Somalia  1977     4353666
# 1398  Somalia  1982     5828892
# 1399  Somalia  1987     6921858
# 1400  Somalia  1992     6099799
# 1401  Somalia  1997     6633514
# 1402  Somalia  2002     7753310
# 1403  Somalia  2007     9118773

# %%
k=df[df['country']=='Kenya']
k
# Out:
#     country  year  population
# 816   Kenya  1952     6464046
# 817   Kenya  1957     7454779
# 818   Kenya  1962     8678557
# 819   Kenya  1967    10191512
# 820   Kenya  1972    12044785
# 821   Kenya  1977    14500404
# 822   Kenya  1982    17661452
# 823   Kenya  1987    21198082
# 824   Kenya  1992    25020539
# 825   Kenya  1997    28263827
# 826   Kenya  2002    31386842
# 827   Kenya  2007    35610177

# %%
sns.set_style('whitegrid')
plt.plot(som.year, som.population, 'y', marker='*', lw=1)
plt.title('popilation of somalia since 1954')
plt.ylabel('pouplation')
plt.xlabel('year')
plt.show()

# %%
sns.set_style('whitegrid')
plt.plot(som.year, som.population, 'y', marker='*', lw=1, label='somalia')
plt.plot(k.year, k.population, 'g', marker='*', lw=1, label='Kenya')
plt.title('popilations Som Vs K since 1954')
plt.ylabel('pouplation')
plt.xlabel('year')
plt.legend()
plt.show()

# %%
data=sns.load_dataset('tips')

data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
data[['sex']]
# Out:
#         sex
# 0    Female
# 1      Male
# 2      Male
# 3      Male
# 4    Female
# ..      ...
# 239    Male
# 240  Female
# 241    Male
# 242    Male
# 243  Female
#
# [244 rows x 1 columns]

# %%
data.sex.value_counts(normalize=True)*100
# Out:
# Male      64.344262
# Female    35.655738
# Name: sex, dtype: float64

# %%
percent=data.sex.value_counts(normalize=True)*100
percent.plot(kind='pie', autopct='%1.2f%%')
plt.show()
